# %% [markdown]
# # Loading Dependencies

# %%
# Dependencies to Visualize the model
import tensorflow as tf
# %matplotlib inline
from IPython.display import Image, SVG
import matplotlib.pyplot as plt
import numpy as np
# Setting seed for reproducibility
np.random.seed(0)

# Filepaths, pandas, numpy, Tensorflow, and scikit-image
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import skimage as sk

# %% [markdown]
# # Stratify Images in Main Image Repository

# %%
import os
import shutil
import pandas as pd
from sklearn.model_selection import train_test_split

# Read the CSV file
csv_file = "Resources/HAM10000_metadata.csv"
metadata = pd.read_csv(csv_file)

# Define the source directory where all the images are located
source_dir = "Resources/Skin Cancer"

# Define the target directories for train and val splits
train_dir = "Resources/Skin Cancer/train"
val_dir = "Resources/Skin Cancer/val"

# Define the split ratio (e.g., 0.8 for 80% train, 0.2 for 20% val)
split_ratio = 0.8

# Create the target directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

# Get the unique class labels
class_labels = metadata["dx"].unique()

# Create subdirectories for each class in train and val directories
for label in class_labels:
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(val_dir, label), exist_ok=True)

# Split the metadata into train and validation sets using stratified splitting
# Stratify was required here to ensure that an 80-20 split occured for all classes in the dataset, not just an 80-20 split of the entire dataset.
train_metadata, val_metadata = train_test_split(
    metadata, stratify=metadata["dx"], test_size=1 - split_ratio, random_state=42
)

# Move or copy the images to the respective train and validation directories
for _, row in train_metadata.iterrows():
    image_id = row["image_id"]
    image_path = os.path.join(source_dir, f"{image_id}.jpg")
    class_label = row["dx"]
    target_dir = os.path.join(train_dir, class_label)
    shutil.copy(image_path, target_dir)

for _, row in val_metadata.iterrows():
    image_id = row["image_id"]
    image_path = os.path.join(source_dir, f"{image_id}.jpg")
    class_label = row["dx"]
    target_dir = os.path.join(val_dir, class_label)
    shutil.copy(image_path, target_dir)

print("Stratified splitting and image organization completed.")

# %% [markdown]
# # Preprocessing of Images

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the path to your image directory
image_directory = "Resources/Skin Cancer"

# Defining original image size
image_size = (600, 450)

# Define the batch size
batch_size = 32

# EDIT THIS OUT 
# Create an ImageDataGenerator for data augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,  # Normalize pixel values
    # rotation_range=20,  # Randomly rotate images by 20 degrees
    # width_shift_range=0.2,  # Randomly shift images horizontally by 20%
    # height_shift_range=0.2,  # Randomly shift images vertically by 20%
    # horizontal_flip=True,  # Randomly flip images horizontally
    # zoom_range=0.2,  # Randomly zoom images by 20%
)

# Load and preprocess the train dataset with data augmentation
train_dataset = train_datagen.flow_from_directory(
    directory=os.path.join(image_directory, "train"),  # Use the 'train' directory
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    seed=42,
)

# Create an ImageDataGenerator for validation data (no augmentation)
val_datagen = ImageDataGenerator(rescale=1.0 / 255)  # Normalize pixel values

# Load and preprocess the validation dataset without data augmentation
val_dataset = val_datagen.flow_from_directory(
    directory=os.path.join(image_directory, "val"),  # Use the 'val' directory
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
    seed=42,
)

# Print the class names
class_names = list(train_dataset.class_indices.keys())
print("Class Names:", class_names)

# Print the shape of the datasets
print("Train Dataset Shape:", train_dataset.image_shape)
print("Validation Dataset Shape:", val_dataset.image_shape)
# Out:
# Found 8012 images belonging to 7 classes.
# Found 2003 images belonging to 7 classes.
# Class Names: ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
# Train Dataset Shape: (600, 450, 3)
# Validation Dataset Shape: (600, 450, 3)

# %% [markdown]
# # Step-by-step Model Building
# This section contains a cell-by-cell break down of the model creation, and allows for the testing of singular models

# %%
# Importing Dependencies
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau
import os
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
import csv

# %% [markdown]
# ### Choose an Architecture

# %%
# Choose an Architecture
architecture = "InceptionV3"  # Options: "VGG16", "ResNet50", "InceptionV3"

# Set the input shape and preprocessing function based on the selected architecture
if architecture == "VGG16":
    input_shape = (224, 224, 3)
    preprocessing_function = tf.keras.applications.vgg16.preprocess_input
if architecture == "resnet50":
    input_shape = (224, 224, 3)
    preprocessing_function = tf.keras.applications.resnet.preprocess_input
elif architecture == "InceptionV3":
    input_shape = (299, 299, 3)
    preprocessing_function = tf.keras.applications.inception_v3.preprocess_input

# %%
# Load and preprocess data using tf.keras.preprocessing
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocessing_function,
    # rotation_range=20,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # horizontal_flip=True,
)

train_dataset = train_datagen.flow_from_directory(
    "Resources/Skin Cancer/train",
    target_size=input_shape[:2],
    batch_size=32,
    class_mode="categorical",
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocessing_function)

val_dataset = val_datagen.flow_from_directory(
    "Resources/Skin Cancer/val",
    target_size=input_shape[:2],
    batch_size=32,
    class_mode="categorical",
)

# %% [markdown]
# ### Set base_model

# %%
# Define the pre-trained model architecture
if architecture == "VGG16":
    base_model = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
elif architecture == "ResNet50":
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
elif architecture == "InceptionV3":
    base_model = InceptionV3(weights="imagenet", include_top=False, input_shape=input_shape)

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# ### Custom Layering

# %%
# Get the number of unique classes from the train_dataset
num_classes = len(train_dataset.class_indices)

# Add custom layers on top of the pre-trained model
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation="relu")(x)
x = Dropout(0.5)(x)
num_classes = len(train_dataset.class_indices)
predictions = Dense(num_classes, activation="softmax")(x)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# %% [markdown]
# ### Choose an Optimizer

# %%
# Choose an Optimizer
optimizer_name = "Adam"  # Options: "Adam", "RMSprop", "SGD"

if optimizer_name == "Adam":
    optimizer = Adam(learning_rate=0.001)
elif optimizer_name == "RMSprop":
    optimizer = RMSprop(learning_rate=0.001)
elif optimizer_name == "SGD":
    optimizer = SGD(learning_rate=0.001, momentum=0.9)

lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, verbose=1)

# Compile the model
model.compile(
    optimizer=optimizer,
    loss="categorical_crossentropy",
    metrics=["accuracy", Precision(), Recall(), AUC()],
)

# %% [markdown]
# ### Create Callbacks for TensorBoard and CSV tracking

# %%
# Create callbacks
tensorboard_callback = TensorBoard(log_dir=f"./logs/{architecture}_{optimizer_name}", histogram_freq=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"models/model_{architecture}_{optimizer_name}.weights.h5",
    save_weights_only=True,
    save_best_only=True,
    monitor="val_loss",
    verbose=1,
)
csv_logger = CSVLogger(f"models/model_{architecture}_{optimizer_name}_training.csv")

# %% [markdown]
# ### Run Model

# %%
# Train the model with callbacks
epochs = 10
history = model.fit(
    train_dataset,
    steps_per_epoch=train_dataset.samples // 32,
    validation_data=val_dataset,
    validation_steps=val_dataset.samples // 32,
    epochs=epochs,
    callbacks=[tensorboard_callback, lr_scheduler, checkpoint_callback, csv_logger],
)

# %% [markdown]
# ### Evaluate Model

# %%
# Evaluate the model on the validation set and print the results
loss, accuracy, precision, recall, auc = model.evaluate(val_dataset)
print(f"Model: {architecture}, Optimizer: {optimizer_name}")
print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")
print(f"Validation Precision: {precision:.4f}")
print(f"Validation Recall: {recall:.4f}")
print(f"Validation AUC-ROC: {auc:.4f}")

# Save the model
model.save(f"models/model_{architecture}_{optimizer_name}.h5")

# %% [markdown]
# # Continuous Testing
# This section contains a conglomerated model run. It was created so that the models could be tested overnight. I'm going to bed now.

# %%
# Importing Dependencies
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger

import csv
import os

from sklearn.utils import class_weight

# ///////////////////////////////////////////////////////////////////////////////////////////
# CHECK RUN NUMBER BEFORE RUNNING
# Run Number - use to create new directory or add to existing directory

run_number = 3
run_dir = f"run{run_number}"
os.makedirs(run_dir, exist_ok=True)


# ///////////////////////////////////////////////////////////////////////////////////////////

# Creating a CSV file to store the model results
csv_file = "model_results.csv"
fieldnames = [
    "architecture",
    "optimizer",
    "loss",
    "accuracy",
    "precision",
    "recall",
    "auc",
]

# Write the header to the CSV file. Data is written to the file after model_result
with open(csv_file, mode="w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()

batch_size = 32
architectures = ["InceptionV3"] # Options: "VGG16", "ResNet50", "InceptionV3"
optimizers = ["Adam"] # Options: "Adam", "RMSprop", "SGD"

# Create directory to store models
models_dir = f"{run_dir}/models"
os.makedirs(models_dir, exist_ok=True)

# Initialize model_results to store the evaluation results
model_results = []

for architecture in architectures:
    # Set the input shape and preprocessing function based on the selected architecture
    if architecture == "VGG16" or architecture == "ResNet50":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.vgg16.preprocess_input
    elif architecture == "ResNet50":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.resnet50.preprocess_input
    elif architecture == "InceptionV3":
        input_shape = (299, 299, 3)
        preprocessing_function = tf.keras.applications.inception_v3.preprocess_input

    # Load and preprocess data using tf.keras.preprocessing
    # This adds data augmentation to the training dataset
    train_datagen = ImageDataGenerator(
        preprocessing_function=preprocessing_function,
        # rotation_range=20,
        # width_shift_range=0.2,
        # height_shift_range=0.2,
        # horizontal_flip=True,
    )

    train_dataset = train_datagen.flow_from_directory(
        "Resources/Skin Cancer/train",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    
    val_datagen = ImageDataGenerator(preprocessing_function=preprocessing_function)

    # Define the validation dataset without data augmentation
    val_dataset = val_datagen.flow_from_directory(
        "Resources/Skin Cancer/val",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    # Define the pre-trained model architecture. Will select proper model based on current 'architecture' in for loop
    if architecture == "VGG16":
        base_model = VGG16(
            weights="imagenet", include_top=False, input_shape=input_shape
        )
    elif architecture == "ResNet50":
        base_model = ResNet50(
            weights="imagenet", include_top=False, input_shape=input_shape
        )
    elif architecture == "InceptionV3":
        base_model = InceptionV3(
            weights="imagenet", include_top=False, input_shape=input_shape
        )

    # Freeze the layers of the pre-trained model
    for layer in base_model.layers:
        layer.trainable = False

    # Get the number of unique classes from the train_dataset
    num_classes = len(train_dataset.class_indices)

    # Add custom layers on top of the pre-trained model
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation="softmax")(x)

    # Create the final model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Step through and adjust for each optimizer
    for optimizer_name in optimizers:
        # Define the optimizer
        if optimizer_name == "Adam":
            optimizer = Adam(learning_rate=0.001)
        elif optimizer_name == "RMSprop":
            optimizer = RMSprop(learning_rate=0.001)
        elif optimizer_name == "SGD":
            optimizer = SGD(learning_rate=0.001, momentum=0.9)

        # Create learning rate scheduler that monitors validation loss
        lr_scheduler = ReduceLROnPlateau(
            monitor="val_loss", factor=0.1, patience=5, verbose=1
        )

        # Compile the model
        model.compile(
            optimizer=optimizer,
            loss="categorical_crossentropy",
            metrics=["accuracy", Precision(), Recall(), AUC()],
        )

        # Create a TensorBoard callback with a separate log directory for each model and optimizer
        tensorboard_callback = TensorBoard(
            log_dir=f"./{run_dir}/logs/{architecture}_{optimizer_name}", histogram_freq=1
        )

        # Create an EarlyStopping callback to prevent overfitting
        early_stopping = EarlyStopping(
            monitor="val_loss", patience=5, restore_best_weights=True
        )

        # Create a ModelCheckpoint callback to save the best model weights
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath=os.path.join(
                models_dir, f"model_{architecture}_{optimizer_name}.weights.h5"
            ),
            save_weights_only=True,
            save_best_only=True,
            monitor="val_loss",
            verbose=1,
        )

        # Create a CSVLogger callback with keras
        csv_logger = CSVLogger(
            os.path.join(
                models_dir, f"model_{architecture}_{optimizer_name}_training.csv"
            )
        )

        # IMPORTANT: RESEARACH CLASS WEIGHTING
        # Calculate class weights
        # This step is required, as some of the classes are imbalanced, in particular, the val classes
        class_weights = class_weight.compute_class_weight(
            'balanced',
            classes=np.unique(train_dataset.classes),
            y=train_dataset.classes
        )
        class_weight_dict = dict(enumerate(class_weights))

        # Train the model with the checkpoint callback and weights
        epochs = 150
        history = model.fit(
            train_dataset,
            steps_per_epoch=train_dataset.samples // batch_size,
            validation_data=val_dataset,
            validation_steps=val_dataset.samples // batch_size,
            epochs=epochs,
            class_weight=class_weight_dict,
            callbacks=[tensorboard_callback, lr_scheduler, checkpoint_callback, csv_logger],
        )

        # Save the optimizer state to avoid retraining the model
        model.save(
            os.path.join(models_dir, f"model_{architecture}_{optimizer_name}.h5")
        )

        # Evaluate the model on the validation set and print the results
        loss, accuracy, precision, recall, auc = model.evaluate(val_dataset)
        print(f"Model: {architecture}, Optimizer: {optimizer_name}")
        print(f"Validation Loss: {loss:.4f}")
        print(f"Validation Accuracy: {accuracy:.4f}")
        print(f"Validation Precision: {precision:.4f}")
        print(f"Validation Recall: {recall:.4f}")
        print(f"Validation AUC-ROC: {auc:.4f}")

        # Append the model results to the list
        model_result = {
            "architecture": architecture,
            "optimizer": optimizer_name,
            "loss": loss,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "auc": auc,
        }
        model_results.append(model_result)

        # Write the current model result to the CSV file
        with open(csv_file, mode="a", newline="") as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writerow(model_result)

        # Save the model
        model.save(
            os.path.join(models_dir, f"model_{architecture}_{optimizer_name}.h5")
        )
# Out:
# Found 8012 images belonging to 7 classes.
# Found 2003 images belonging to 7 classes.
# Epoch 1/150
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.2917 - auc: 0.7009 - loss: 2.1364 - precision: 0.3569 - recall: 0.1233
# Epoch 1: val_loss improved from inf to 1.48985, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.2920 - auc: 0.7011 - loss: 2.1349 - precision: 0.3575 - recall: 0.1234 - val_accuracy: 0.4632 - val_auc: 0.8005 - val_loss: 1.4898 - val_precision: 0.8329 - val_recall: 0.1507 - learning_rate: 0.0010
# Epoch 2/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:29 843ms/step - accuracy: 0.3125 - auc: 0.7351 - loss: 2.0954 - precision: 0.6667 - recall: 0.1875
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss improved from 1.48985 to 0.69689, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.3125 - auc: 0.7351 - loss: 1.0519 - precision: 0.6667 - recall: 0.1875 - val_accuracy: 0.5263 - val_auc: 0.8250 - val_loss: 0.6969 - val_precision: 0.8333 - val_recall: 0.2632 - learning_rate: 0.0010
# Epoch 3/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.4667 - auc: 0.8154 - loss: 1.4149 - precision: 0.6645 - recall: 0.2501
# Epoch 3: val_loss did not improve from 0.69689
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.4668 - auc: 0.8154 - loss: 1.4148 - precision: 0.6645 - recall: 0.2501 - val_accuracy: 0.6573 - val_auc: 0.9284 - val_loss: 0.9624 - val_precision: 0.8655 - val_recall: 0.4476 - learning_rate: 0.0010
# Epoch 4/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:19 801ms/step - accuracy: 0.6250 - auc: 0.9233 - loss: 0.9060 - precision: 0.8182 - recall: 0.5625
# Epoch 4: val_loss improved from 0.69689 to 0.50999, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6250 - auc: 0.9233 - loss: 0.4548 - precision: 0.8182 - recall: 0.5625 - val_accuracy: 0.6842 - val_auc: 0.9134 - val_loss: 0.5100 - val_precision: 1.0000 - val_recall: 0.4211 - learning_rate: 0.0010
# Epoch 5/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.5092 - auc: 0.8535 - loss: 1.2941 - precision: 0.6957 - recall: 0.3111
# Epoch 5: val_loss did not improve from 0.50999
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.5092 - auc: 0.8535 - loss: 1.2941 - precision: 0.6957 - recall: 0.3111 - val_accuracy: 0.5766 - val_auc: 0.8919 - val_loss: 1.1485 - val_precision: 0.7698 - val_recall: 0.3422 - learning_rate: 0.0010
# Epoch 6/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:20 806ms/step - accuracy: 0.3438 - auc: 0.8556 - loss: 0.7817 - precision: 0.6667 - recall: 0.1875
# Epoch 6: val_loss did not improve from 0.50999
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.3438 - auc: 0.8556 - loss: 0.3924 - precision: 0.6667 - recall: 0.1875 - val_accuracy: 0.4211 - val_auc: 0.8403 - val_loss: 0.6436 - val_precision: 0.8571 - val_recall: 0.3158 - learning_rate: 0.0010
# Epoch 7/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - accuracy: 0.5266 - auc: 0.8657 - loss: 1.2248 - precision: 0.6809 - recall: 0.3458
# Epoch 7: val_loss did not improve from 0.50999
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.5266 - auc: 0.8657 - loss: 1.2247 - precision: 0.6809 - recall: 0.3458 - val_accuracy: 0.5368 - val_auc: 0.8745 - val_loss: 1.2140 - val_precision: 0.7066 - val_recall: 0.3422 - learning_rate: 0.0010
# Epoch 8/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:40 886ms/step - accuracy: 0.3750 - auc: 0.8145 - loss: 0.6264 - precision: 0.3750 - recall: 0.1875
# Epoch 8: val_loss did not improve from 0.50999
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.3750 - auc: 0.8145 - loss: 0.3144 - precision: 0.3750 - recall: 0.1875 - val_accuracy: 0.6316 - val_auc: 0.9174 - val_loss: 0.5465 - val_precision: 0.3333 - val_recall: 0.1053 - learning_rate: 0.0010
# Epoch 9/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.5381 - auc: 0.8650 - loss: 1.1953 - precision: 0.6593 - recall: 0.3649
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 9: val_loss did not improve from 0.50999
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.5381 - auc: 0.8650 - loss: 1.1950 - precision: 0.6594 - recall: 0.3650 - val_accuracy: 0.6139 - val_auc: 0.9047 - val_loss: 1.0556 - val_precision: 0.7912 - val_recall: 0.4355 - learning_rate: 0.0010
# Epoch 10/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:24 822ms/step - accuracy: 0.5625 - auc: 0.8767 - loss: 0.9415 - precision: 0.7619 - recall: 0.5000
# Epoch 10: val_loss improved from 0.50999 to 0.48342, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5625 - auc: 0.8767 - loss: 0.4726 - precision: 0.7619 - recall: 0.5000 - val_accuracy: 0.7368 - val_auc: 0.9224 - val_loss: 0.4834 - val_precision: 0.8182 - val_recall: 0.4737 - learning_rate: 1.0000e-04
# Epoch 11/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.5850 - auc: 0.8961 - loss: 1.0932 - precision: 0.7569 - recall: 0.4264
# Epoch 11: val_loss did not improve from 0.48342
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.5850 - auc: 0.8961 - loss: 1.0930 - precision: 0.7569 - recall: 0.4264 - val_accuracy: 0.6129 - val_auc: 0.9151 - val_loss: 1.0061 - val_precision: 0.7724 - val_recall: 0.4567 - learning_rate: 1.0000e-04
# Epoch 12/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:20 805ms/step - accuracy: 0.6875 - auc: 0.9251 - loss: 2.1080 - precision: 0.8125 - recall: 0.4062
# Epoch 12: val_loss improved from 0.48342 to 0.44362, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6875 - auc: 0.9251 - loss: 1.0582 - precision: 0.8125 - recall: 0.4062 - val_accuracy: 0.6316 - val_auc: 0.9342 - val_loss: 0.4436 - val_precision: 0.8182 - val_recall: 0.4737 - learning_rate: 1.0000e-04
# Epoch 13/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 823ms/step - accuracy: 0.5912 - auc: 0.9043 - loss: 0.9753 - precision: 0.7358 - recall: 0.4441
# Epoch 13: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.5912 - auc: 0.9043 - loss: 0.9753 - precision: 0.7358 - recall: 0.4441 - val_accuracy: 0.6290 - val_auc: 0.9220 - val_loss: 0.9667 - val_precision: 0.7909 - val_recall: 0.4803 - learning_rate: 1.0000e-04
# Epoch 14/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 787ms/step - accuracy: 0.6250 - auc: 0.9263 - loss: 0.8978 - precision: 0.8421 - recall: 0.5000
# Epoch 14: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9263 - loss: 0.4507 - precision: 0.8421 - recall: 0.5000 - val_accuracy: 0.5263 - val_auc: 0.8820 - val_loss: 0.5870 - val_precision: 0.7000 - val_recall: 0.3684 - learning_rate: 1.0000e-04
# Epoch 15/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.6034 - auc: 0.9106 - loss: 0.9781 - precision: 0.7607 - recall: 0.4574
# Epoch 15: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 0.6033 - auc: 0.9106 - loss: 0.9781 - precision: 0.7606 - recall: 0.4574 - val_accuracy: 0.6205 - val_auc: 0.9150 - val_loss: 1.0029 - val_precision: 0.7637 - val_recall: 0.4708 - learning_rate: 1.0000e-04
# Epoch 16/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:24 821ms/step - accuracy: 0.5000 - auc: 0.8592 - loss: 0.6932 - precision: 0.6316 - recall: 0.3750
# Epoch 16: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5000 - auc: 0.8592 - loss: 0.3480 - precision: 0.6316 - recall: 0.3750 - val_accuracy: 0.5789 - val_auc: 0.9190 - val_loss: 0.5309 - val_precision: 0.7500 - val_recall: 0.3158 - learning_rate: 1.0000e-04
# Epoch 17/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 856ms/step - accuracy: 0.6030 - auc: 0.9088 - loss: 0.9362 - precision: 0.7458 - recall: 0.4611
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 17: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6030 - auc: 0.9088 - loss: 0.9362 - precision: 0.7458 - recall: 0.4612 - val_accuracy: 0.6260 - val_auc: 0.9190 - val_loss: 0.9822 - val_precision: 0.7709 - val_recall: 0.4783 - learning_rate: 1.0000e-04
# Epoch 18/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:17 794ms/step - accuracy: 0.5938 - auc: 0.9134 - loss: 0.6401 - precision: 0.7895 - recall: 0.4688
# Epoch 18: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5938 - auc: 0.9134 - loss: 0.3213 - precision: 0.7895 - recall: 0.4688 - val_accuracy: 0.5263 - val_auc: 0.8472 - val_loss: 0.6751 - val_precision: 0.5000 - val_recall: 0.3158 - learning_rate: 1.0000e-05
# Epoch 19/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - accuracy: 0.6125 - auc: 0.9116 - loss: 0.9222 - precision: 0.7559 - recall: 0.4699
# Epoch 19: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.6125 - auc: 0.9116 - loss: 0.9222 - precision: 0.7559 - recall: 0.4699 - val_accuracy: 0.6255 - val_auc: 0.9195 - val_loss: 0.9790 - val_precision: 0.7669 - val_recall: 0.4808 - learning_rate: 1.0000e-05
# Epoch 20/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:19 802ms/step - accuracy: 0.5938 - auc: 0.9158 - loss: 0.7610 - precision: 0.7895 - recall: 0.4688
# Epoch 20: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5938 - auc: 0.9158 - loss: 0.3820 - precision: 0.7895 - recall: 0.4688 - val_accuracy: 0.6316 - val_auc: 0.9266 - val_loss: 0.4671 - val_precision: 0.9091 - val_recall: 0.5263 - learning_rate: 1.0000e-05
# Epoch 21/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.6004 - auc: 0.9071 - loss: 0.9045 - precision: 0.7526 - recall: 0.4655
# Epoch 21: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.6005 - auc: 0.9071 - loss: 0.9046 - precision: 0.7526 - recall: 0.4655 - val_accuracy: 0.6300 - val_auc: 0.9214 - val_loss: 0.9678 - val_precision: 0.7776 - val_recall: 0.4864 - learning_rate: 1.0000e-05
# Epoch 22/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 789ms/step - accuracy: 0.5938 - auc: 0.8892 - loss: 1.0377 - precision: 0.7895 - recall: 0.4688
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 22: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5938 - auc: 0.8892 - loss: 0.5209 - precision: 0.7895 - recall: 0.4688 - val_accuracy: 0.5263 - val_auc: 0.9037 - val_loss: 0.5375 - val_precision: 0.5385 - val_recall: 0.3684 - learning_rate: 1.0000e-05
# Epoch 23/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.6086 - auc: 0.9134 - loss: 0.8815 - precision: 0.7429 - recall: 0.4652
# Epoch 23: val_loss did not improve from 0.44362
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6086 - auc: 0.9134 - loss: 0.8816 - precision: 0.7430 - recall: 0.4652 - val_accuracy: 0.6270 - val_auc: 0.9206 - val_loss: 0.9726 - val_precision: 0.7730 - val_recall: 0.4824 - learning_rate: 1.0000e-06
# Epoch 24/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:19 802ms/step - accuracy: 0.5938 - auc: 0.8973 - loss: 1.7290 - precision: 0.7500 - recall: 0.3750
# Epoch 24: val_loss improved from 0.44362 to 0.30418, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5938 - auc: 0.8973 - loss: 0.8679 - precision: 0.7500 - recall: 0.3750 - val_accuracy: 0.8421 - val_auc: 0.9693 - val_loss: 0.3042 - val_precision: 0.9333 - val_recall: 0.7368 - learning_rate: 1.0000e-06
# Epoch 25/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.6108 - auc: 0.9137 - loss: 0.9015 - precision: 0.7593 - recall: 0.4750
# Epoch 25: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6108 - auc: 0.9137 - loss: 0.9015 - precision: 0.7592 - recall: 0.4750 - val_accuracy: 0.6280 - val_auc: 0.9212 - val_loss: 0.9691 - val_precision: 0.7746 - val_recall: 0.4849 - learning_rate: 1.0000e-06
# Epoch 26/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 790ms/step - accuracy: 0.6562 - auc: 0.9428 - loss: 0.6760 - precision: 0.9444 - recall: 0.5312
# Epoch 26: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6562 - auc: 0.9428 - loss: 0.3394 - precision: 0.9444 - recall: 0.5312 - val_accuracy: 0.6842 - val_auc: 0.9303 - val_loss: 0.4629 - val_precision: 0.8182 - val_recall: 0.4737 - learning_rate: 1.0000e-06
# Epoch 27/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.6079 - auc: 0.9107 - loss: 0.9181 - precision: 0.7452 - recall: 0.4630
# Epoch 27: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6079 - auc: 0.9107 - loss: 0.9181 - precision: 0.7452 - recall: 0.4630 - val_accuracy: 0.6265 - val_auc: 0.9208 - val_loss: 0.9712 - val_precision: 0.7739 - val_recall: 0.4849 - learning_rate: 1.0000e-06
# Epoch 28/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 790ms/step - accuracy: 0.6875 - auc: 0.9162 - loss: 0.8407 - precision: 0.7391 - recall: 0.5312
# Epoch 28: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc: 0.9162 - loss: 0.4221 - precision: 0.7391 - recall: 0.5312 - val_accuracy: 0.7895 - val_auc: 0.9661 - val_loss: 0.3215 - val_precision: 0.8667 - val_recall: 0.6842 - learning_rate: 1.0000e-06
# Epoch 29/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.6093 - auc: 0.9153 - loss: 0.9099 - precision: 0.7503 - recall: 0.4729
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 29: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6093 - auc: 0.9153 - loss: 0.9099 - precision: 0.7503 - recall: 0.4729 - val_accuracy: 0.6265 - val_auc: 0.9213 - val_loss: 0.9683 - val_precision: 0.7739 - val_recall: 0.4864 - learning_rate: 1.0000e-06
# Epoch 30/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:10 765ms/step - accuracy: 0.5000 - auc: 0.9062 - loss: 0.9446 - precision: 0.6000 - recall: 0.3750
# Epoch 30: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5000 - auc: 0.9062 - loss: 0.4742 - precision: 0.6000 - recall: 0.3750 - val_accuracy: 0.7368 - val_auc: 0.9234 - val_loss: 0.4649 - val_precision: 0.9167 - val_recall: 0.5789 - learning_rate: 1.0000e-07
# Epoch 31/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.6111 - auc: 0.9130 - loss: 0.9171 - precision: 0.7464 - recall: 0.4702
# Epoch 31: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.6111 - auc: 0.9130 - loss: 0.9171 - precision: 0.7464 - recall: 0.4702 - val_accuracy: 0.6270 - val_auc: 0.9211 - val_loss: 0.9696 - val_precision: 0.7745 - val_recall: 0.4864 - learning_rate: 1.0000e-07
# Epoch 32/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 789ms/step - accuracy: 0.5312 - auc: 0.8810 - loss: 1.3635 - precision: 0.6667 - recall: 0.3750
# Epoch 32: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5312 - auc: 0.8810 - loss: 0.6845 - precision: 0.6667 - recall: 0.3750 - val_accuracy: 0.6842 - val_auc: 0.9527 - val_loss: 0.3947 - val_precision: 0.8462 - val_recall: 0.5789 - learning_rate: 1.0000e-07
# Epoch 33/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.6105 - auc: 0.9124 - loss: 0.9611 - precision: 0.7533 - recall: 0.4697
# Epoch 33: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6105 - auc: 0.9124 - loss: 0.9609 - precision: 0.7533 - recall: 0.4697 - val_accuracy: 0.6280 - val_auc: 0.9216 - val_loss: 0.9668 - val_precision: 0.7755 - val_recall: 0.4874 - learning_rate: 1.0000e-07
# Epoch 34/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:22 813ms/step - accuracy: 0.7188 - auc: 0.9252 - loss: 1.4070 - precision: 0.8333 - recall: 0.6250
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 34: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7188 - auc: 0.9252 - loss: 0.7063 - precision: 0.8333 - recall: 0.6250 - val_accuracy: 0.5789 - val_auc: 0.9040 - val_loss: 0.5376 - val_precision: 0.7500 - val_recall: 0.4737 - learning_rate: 1.0000e-07
# Epoch 35/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.6127 - auc: 0.9119 - loss: 0.9211 - precision: 0.7536 - recall: 0.4680
# Epoch 35: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6127 - auc: 0.9119 - loss: 0.9211 - precision: 0.7536 - recall: 0.4680 - val_accuracy: 0.6280 - val_auc: 0.9220 - val_loss: 0.9647 - val_precision: 0.7772 - val_recall: 0.4889 - learning_rate: 1.0000e-08
# Epoch 36/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:18 798ms/step - accuracy: 0.5625 - auc: 0.9247 - loss: 0.5138 - precision: 0.6957 - recall: 0.5000
# Epoch 36: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5625 - auc: 0.9247 - loss: 0.2579 - precision: 0.6957 - recall: 0.5000 - val_accuracy: 0.5789 - val_auc: 0.8583 - val_loss: 0.6476 - val_precision: 0.5455 - val_recall: 0.3158 - learning_rate: 1.0000e-08
# Epoch 37/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.6084 - auc: 0.9124 - loss: 0.8979 - precision: 0.7517 - recall: 0.4609
# Epoch 37: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6085 - auc: 0.9124 - loss: 0.8979 - precision: 0.7517 - recall: 0.4610 - val_accuracy: 0.6280 - val_auc: 0.9219 - val_loss: 0.9654 - val_precision: 0.7773 - val_recall: 0.4874 - learning_rate: 1.0000e-08
# Epoch 38/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:22 813ms/step - accuracy: 0.6875 - auc: 0.9182 - loss: 1.5652 - precision: 0.8235 - recall: 0.4375
# Epoch 38: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc: 0.9182 - loss: 0.7857 - precision: 0.8235 - recall: 0.4375 - val_accuracy: 0.5789 - val_auc: 0.8767 - val_loss: 0.6100 - val_precision: 0.6000 - val_recall: 0.4737 - learning_rate: 1.0000e-08
# Epoch 39/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6005 - auc: 0.9104 - loss: 0.9230 - precision: 0.7490 - recall: 0.4612
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 39: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6006 - auc: 0.9104 - loss: 0.9229 - precision: 0.7491 - recall: 0.4612 - val_accuracy: 0.6270 - val_auc: 0.9212 - val_loss: 0.9692 - val_precision: 0.7743 - val_recall: 0.4859 - learning_rate: 1.0000e-08
# Epoch 40/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:13 777ms/step - accuracy: 0.5938 - auc: 0.9040 - loss: 0.8667 - precision: 0.7500 - recall: 0.5625
# Epoch 40: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5938 - auc: 0.9040 - loss: 0.4351 - precision: 0.7500 - recall: 0.5625 - val_accuracy: 0.6842 - val_auc: 0.9439 - val_loss: 0.4124 - val_precision: 0.8571 - val_recall: 0.6316 - learning_rate: 1.0000e-09
# Epoch 41/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6181 - auc: 0.9147 - loss: 0.8905 - precision: 0.7712 - recall: 0.4712
# Epoch 41: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6181 - auc: 0.9147 - loss: 0.8906 - precision: 0.7711 - recall: 0.4712 - val_accuracy: 0.6290 - val_auc: 0.9215 - val_loss: 0.9673 - val_precision: 0.7763 - val_recall: 0.4879 - learning_rate: 1.0000e-09
# Epoch 42/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:12 774ms/step - accuracy: 0.5625 - auc: 0.8897 - loss: 1.1181 - precision: 0.6842 - recall: 0.4062
# Epoch 42: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5625 - auc: 0.8897 - loss: 0.5613 - precision: 0.6842 - recall: 0.4062 - val_accuracy: 0.4737 - val_auc: 0.9134 - val_loss: 0.5075 - val_precision: 0.6667 - val_recall: 0.4211 - learning_rate: 1.0000e-09
# Epoch 43/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6046 - auc: 0.9105 - loss: 0.9138 - precision: 0.7591 - recall: 0.4655
# Epoch 43: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6046 - auc: 0.9105 - loss: 0.9138 - precision: 0.7591 - recall: 0.4655 - val_accuracy: 0.6275 - val_auc: 0.9212 - val_loss: 0.9690 - val_precision: 0.7746 - val_recall: 0.4884 - learning_rate: 1.0000e-09
# Epoch 44/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:33 857ms/step - accuracy: 0.7188 - auc: 0.9269 - loss: 0.7142 - precision: 0.7917 - recall: 0.5938
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
#
# Epoch 44: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7188 - auc: 0.9269 - loss: 0.3585 - precision: 0.7917 - recall: 0.5938 - val_accuracy: 0.6316 - val_auc: 0.9488 - val_loss: 0.4215 - val_precision: 0.8750 - val_recall: 0.3684 - learning_rate: 1.0000e-09
# Epoch 45/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6023 - auc: 0.9128 - loss: 0.9100 - precision: 0.7568 - recall: 0.4696
# Epoch 45: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6023 - auc: 0.9128 - loss: 0.9101 - precision: 0.7568 - recall: 0.4696 - val_accuracy: 0.6275 - val_auc: 0.9212 - val_loss: 0.9691 - val_precision: 0.7772 - val_recall: 0.4869 - learning_rate: 1.0000e-10
# Epoch 46/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:10 767ms/step - accuracy: 0.5312 - auc: 0.9319 - loss: 0.7045 - precision: 0.6500 - recall: 0.4062
# Epoch 46: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5312 - auc: 0.9319 - loss: 0.3536 - precision: 0.6500 - recall: 0.4062 - val_accuracy: 0.6316 - val_auc: 0.9393 - val_loss: 0.4156 - val_precision: 0.6250 - val_recall: 0.5263 - learning_rate: 1.0000e-10
# Epoch 47/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.6114 - auc: 0.9133 - loss: 0.9060 - precision: 0.7522 - recall: 0.4698
# Epoch 47: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6114 - auc: 0.9133 - loss: 0.9060 - precision: 0.7522 - recall: 0.4698 - val_accuracy: 0.6285 - val_auc: 0.9217 - val_loss: 0.9666 - val_precision: 0.7756 - val_recall: 0.4879 - learning_rate: 1.0000e-10
# Epoch 48/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:10 765ms/step - accuracy: 0.7188 - auc: 0.9449 - loss: 0.5520 - precision: 0.8261 - recall: 0.5938
# Epoch 48: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7188 - auc: 0.9449 - loss: 0.2771 - precision: 0.8261 - recall: 0.5938 - val_accuracy: 0.5263 - val_auc: 0.8975 - val_loss: 0.5453 - val_precision: 0.7273 - val_recall: 0.4211 - learning_rate: 1.0000e-10
# Epoch 49/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.6119 - auc: 0.9147 - loss: 0.8848 - precision: 0.7616 - recall: 0.4724
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
#
# Epoch 49: val_loss did not improve from 0.30418
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6119 - auc: 0.9147 - loss: 0.8850 - precision: 0.7616 - recall: 0.4724 - val_accuracy: 0.6260 - val_auc: 0.9207 - val_loss: 0.9720 - val_precision: 0.7737 - val_recall: 0.4859 - learning_rate: 1.0000e-10
# Epoch 50/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:15 784ms/step - accuracy: 0.6250 - auc: 0.9363 - loss: 0.6747 - precision: 0.8000 - recall: 0.5000
# Epoch 50: val_loss improved from 0.30418 to 0.26447, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6250 - auc: 0.9363 - loss: 0.3387 - precision: 0.8000 - recall: 0.5000 - val_accuracy: 0.7895 - val_auc: 0.9834 - val_loss: 0.2645 - val_precision: 0.9231 - val_recall: 0.6316 - learning_rate: 1.0000e-11
# Epoch 51/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6081 - auc: 0.9106 - loss: 0.9597 - precision: 0.7510 - recall: 0.4644
# Epoch 51: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6081 - auc: 0.9106 - loss: 0.9595 - precision: 0.7510 - recall: 0.4644 - val_accuracy: 0.6280 - val_auc: 0.9216 - val_loss: 0.9669 - val_precision: 0.7767 - val_recall: 0.4874 - learning_rate: 1.0000e-11
# Epoch 52/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:13 779ms/step - accuracy: 0.5312 - auc: 0.9046 - loss: 1.1992 - precision: 0.8333 - recall: 0.4688
# Epoch 52: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5312 - auc: 0.9046 - loss: 0.6020 - precision: 0.8333 - recall: 0.4688 - val_accuracy: 0.5789 - val_auc: 0.9054 - val_loss: 0.5292 - val_precision: 0.6429 - val_recall: 0.4737 - learning_rate: 1.0000e-11
# Epoch 53/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.6279 - auc: 0.9170 - loss: 0.9024 - precision: 0.7622 - recall: 0.4833
# Epoch 53: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6278 - auc: 0.9170 - loss: 0.9025 - precision: 0.7622 - recall: 0.4832 - val_accuracy: 0.6280 - val_auc: 0.9219 - val_loss: 0.9655 - val_precision: 0.7759 - val_recall: 0.4869 - learning_rate: 1.0000e-11
# Epoch 54/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:11 768ms/step - accuracy: 0.5938 - auc: 0.9183 - loss: 0.8566 - precision: 0.7143 - recall: 0.4688
# Epoch 54: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5938 - auc: 0.9183 - loss: 0.4300 - precision: 0.7143 - recall: 0.4688 - val_accuracy: 0.5789 - val_auc: 0.8661 - val_loss: 0.6030 - val_precision: 0.7143 - val_recall: 0.5263 - learning_rate: 1.0000e-11
# Epoch 55/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6200 - auc: 0.9154 - loss: 0.9032 - precision: 0.7604 - recall: 0.4676
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
#
# Epoch 55: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6200 - auc: 0.9154 - loss: 0.9033 - precision: 0.7604 - recall: 0.4676 - val_accuracy: 0.6280 - val_auc: 0.9219 - val_loss: 0.9651 - val_precision: 0.7754 - val_recall: 0.4889 - learning_rate: 1.0000e-11
# Epoch 56/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:12 773ms/step - accuracy: 0.5625 - auc: 0.9150 - loss: 0.7658 - precision: 0.6087 - recall: 0.4375
# Epoch 56: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5625 - auc: 0.9150 - loss: 0.3844 - precision: 0.6087 - recall: 0.4375 - val_accuracy: 0.5789 - val_auc: 0.8601 - val_loss: 0.6253 - val_precision: 0.7500 - val_recall: 0.3158 - learning_rate: 1.0000e-12
# Epoch 57/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6157 - auc: 0.9129 - loss: 0.9373 - precision: 0.7564 - recall: 0.4671
# Epoch 57: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.6157 - auc: 0.9129 - loss: 0.9372 - precision: 0.7564 - recall: 0.4671 - val_accuracy: 0.6275 - val_auc: 0.9216 - val_loss: 0.9668 - val_precision: 0.7753 - val_recall: 0.4869 - learning_rate: 1.0000e-12
# Epoch 58/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:22 814ms/step - accuracy: 0.6250 - auc: 0.9165 - loss: 0.8797 - precision: 0.8421 - recall: 0.5000
# Epoch 58: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9165 - loss: 0.4416 - precision: 0.8421 - recall: 0.5000 - val_accuracy: 0.6316 - val_auc: 0.9042 - val_loss: 0.5381 - val_precision: 0.7692 - val_recall: 0.5263 - learning_rate: 1.0000e-12
# Epoch 59/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.6298 - auc: 0.9203 - loss: 0.8657 - precision: 0.7743 - recall: 0.4885
# Epoch 59: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6298 - auc: 0.9203 - loss: 0.8658 - precision: 0.7742 - recall: 0.4884 - val_accuracy: 0.6280 - val_auc: 0.9213 - val_loss: 0.9683 - val_precision: 0.7755 - val_recall: 0.4874 - learning_rate: 1.0000e-12
# Epoch 60/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:09 763ms/step - accuracy: 0.6562 - auc: 0.9228 - loss: 0.9351 - precision: 0.8636 - recall: 0.5938
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.0000001044244145e-13.
#
# Epoch 60: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6562 - auc: 0.9228 - loss: 0.4694 - precision: 0.8636 - recall: 0.5938 - val_accuracy: 0.5789 - val_auc: 0.9298 - val_loss: 0.4593 - val_precision: 0.7500 - val_recall: 0.4737 - learning_rate: 1.0000e-12
# Epoch 61/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6157 - auc: 0.9122 - loss: 0.9078 - precision: 0.7599 - recall: 0.4765
# Epoch 61: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6157 - auc: 0.9122 - loss: 0.9078 - precision: 0.7599 - recall: 0.4765 - val_accuracy: 0.6275 - val_auc: 0.9209 - val_loss: 0.9705 - val_precision: 0.7757 - val_recall: 0.4864 - learning_rate: 1.0000e-13
# Epoch 62/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:38 876ms/step - accuracy: 0.5312 - auc: 0.8988 - loss: 0.7298 - precision: 0.7000 - recall: 0.4375
# Epoch 62: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5312 - auc: 0.8988 - loss: 0.3664 - precision: 0.7000 - recall: 0.4375 - val_accuracy: 0.6316 - val_auc: 0.9670 - val_loss: 0.3413 - val_precision: 0.7333 - val_recall: 0.5789 - learning_rate: 1.0000e-13
# Epoch 63/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.6122 - auc: 0.9129 - loss: 0.9094 - precision: 0.7514 - recall: 0.4613
# Epoch 63: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6122 - auc: 0.9129 - loss: 0.9093 - precision: 0.7513 - recall: 0.4613 - val_accuracy: 0.6260 - val_auc: 0.9209 - val_loss: 0.9708 - val_precision: 0.7729 - val_recall: 0.4854 - learning_rate: 1.0000e-13
# Epoch 64/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:15 787ms/step - accuracy: 0.7812 - auc: 0.9281 - loss: 0.9057 - precision: 0.8400 - recall: 0.6562
# Epoch 64: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7812 - auc: 0.9281 - loss: 0.4547 - precision: 0.8400 - recall: 0.6562 - val_accuracy: 0.7895 - val_auc: 0.9735 - val_loss: 0.3281 - val_precision: 1.0000 - val_recall: 0.6842 - learning_rate: 1.0000e-13
# Epoch 65/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6079 - auc: 0.9113 - loss: 0.9197 - precision: 0.7530 - recall: 0.4725
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.0000001179769417e-14.
#
# Epoch 65: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6079 - auc: 0.9113 - loss: 0.9197 - precision: 0.7530 - recall: 0.4725 - val_accuracy: 0.6265 - val_auc: 0.9216 - val_loss: 0.9669 - val_precision: 0.7745 - val_recall: 0.4864 - learning_rate: 1.0000e-13
# Epoch 66/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:08 759ms/step - accuracy: 0.6250 - auc: 0.9256 - loss: 0.4602 - precision: 0.8500 - recall: 0.5312
# Epoch 66: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9256 - loss: 0.2310 - precision: 0.8500 - recall: 0.5312 - val_accuracy: 0.7368 - val_auc: 0.9054 - val_loss: 0.5336 - val_precision: 0.8462 - val_recall: 0.5789 - learning_rate: 1.0000e-14
# Epoch 67/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.6158 - auc: 0.9135 - loss: 0.8929 - precision: 0.7516 - recall: 0.4738
# Epoch 67: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6158 - auc: 0.9135 - loss: 0.8929 - precision: 0.7516 - recall: 0.4738 - val_accuracy: 0.6280 - val_auc: 0.9219 - val_loss: 0.9650 - val_precision: 0.7756 - val_recall: 0.4879 - learning_rate: 1.0000e-14
# Epoch 68/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:12 773ms/step - accuracy: 0.6250 - auc: 0.9220 - loss: 0.7117 - precision: 0.8095 - recall: 0.5312
# Epoch 68: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9220 - loss: 0.3573 - precision: 0.8095 - recall: 0.5312 - val_accuracy: 0.5789 - val_auc: 0.8657 - val_loss: 0.6279 - val_precision: 0.7273 - val_recall: 0.4211 - learning_rate: 1.0000e-14
# Epoch 69/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.6030 - auc: 0.9088 - loss: 0.9139 - precision: 0.7536 - recall: 0.4595
# Epoch 69: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6030 - auc: 0.9089 - loss: 0.9139 - precision: 0.7536 - recall: 0.4595 - val_accuracy: 0.6275 - val_auc: 0.9214 - val_loss: 0.9680 - val_precision: 0.7755 - val_recall: 0.4874 - learning_rate: 1.0000e-14
# Epoch 70/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:17 794ms/step - accuracy: 0.3750 - auc: 0.8188 - loss: 1.9605 - precision: 0.5556 - recall: 0.3125
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.0000001518582595e-15.
#
# Epoch 70: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3750 - auc: 0.8188 - loss: 0.9842 - precision: 0.5556 - recall: 0.3125 - val_accuracy: 0.6316 - val_auc: 0.9305 - val_loss: 0.4714 - val_precision: 0.7500 - val_recall: 0.4737 - learning_rate: 1.0000e-14
# Epoch 71/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.6110 - auc: 0.9144 - loss: 0.8943 - precision: 0.7579 - recall: 0.4681
# Epoch 71: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6110 - auc: 0.9144 - loss: 0.8943 - precision: 0.7578 - recall: 0.4681 - val_accuracy: 0.6280 - val_auc: 0.9216 - val_loss: 0.9670 - val_precision: 0.7756 - val_recall: 0.4879 - learning_rate: 1.0000e-15
# Epoch 72/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:11 771ms/step - accuracy: 0.6250 - auc: 0.9336 - loss: 1.7839 - precision: 0.7727 - recall: 0.5312
# Epoch 72: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6250 - auc: 0.9336 - loss: 0.8955 - precision: 0.7727 - recall: 0.5312 - val_accuracy: 0.5789 - val_auc: 0.9037 - val_loss: 0.5279 - val_precision: 0.7273 - val_recall: 0.4211 - learning_rate: 1.0000e-15
# Epoch 73/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6218 - auc: 0.9176 - loss: 0.8809 - precision: 0.7644 - recall: 0.4861
# Epoch 73: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6217 - auc: 0.9176 - loss: 0.8810 - precision: 0.7643 - recall: 0.4860 - val_accuracy: 0.6265 - val_auc: 0.9209 - val_loss: 0.9707 - val_precision: 0.7745 - val_recall: 0.4864 - learning_rate: 1.0000e-15
# Epoch 74/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:11 770ms/step - accuracy: 0.5625 - auc: 0.8780 - loss: 0.8603 - precision: 0.6190 - recall: 0.4062
# Epoch 74: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5625 - auc: 0.8780 - loss: 0.4319 - precision: 0.6190 - recall: 0.4062 - val_accuracy: 0.7368 - val_auc: 0.9732 - val_loss: 0.3315 - val_precision: 0.8462 - val_recall: 0.5789 - learning_rate: 1.0000e-15
# Epoch 75/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.6055 - auc: 0.9109 - loss: 0.9645 - precision: 0.7557 - recall: 0.4709
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.0000001095066122e-16.
#
# Epoch 75: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6056 - auc: 0.9109 - loss: 0.9643 - precision: 0.7557 - recall: 0.4708 - val_accuracy: 0.6260 - val_auc: 0.9211 - val_loss: 0.9695 - val_precision: 0.7753 - val_recall: 0.4869 - learning_rate: 1.0000e-15
# Epoch 76/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:18 797ms/step - accuracy: 0.6250 - auc: 0.9203 - loss: 1.0494 - precision: 0.8261 - recall: 0.5938
# Epoch 76: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9203 - loss: 0.5268 - precision: 0.8261 - recall: 0.5938 - val_accuracy: 0.7895 - val_auc: 0.9566 - val_loss: 0.3946 - val_precision: 0.7692 - val_recall: 0.5263 - learning_rate: 1.0000e-16
# Epoch 77/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.6159 - auc: 0.9130 - loss: 0.8995 - precision: 0.7638 - recall: 0.4752
# Epoch 77: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6159 - auc: 0.9130 - loss: 0.8996 - precision: 0.7638 - recall: 0.4752 - val_accuracy: 0.6285 - val_auc: 0.9224 - val_loss: 0.9623 - val_precision: 0.7746 - val_recall: 0.4884 - learning_rate: 1.0000e-16
# Epoch 78/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:10 765ms/step - accuracy: 0.6250 - auc: 0.8780 - loss: 1.8842 - precision: 0.6957 - recall: 0.5000
# Epoch 78: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6250 - auc: 0.8780 - loss: 0.9459 - precision: 0.6957 - recall: 0.5000 - val_accuracy: 0.5263 - val_auc: 0.8158 - val_loss: 0.7713 - val_precision: 0.8750 - val_recall: 0.3684 - learning_rate: 1.0000e-16
# Epoch 79/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.6148 - auc: 0.9140 - loss: 0.9554 - precision: 0.7492 - recall: 0.4751
# Epoch 79: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6149 - auc: 0.9140 - loss: 0.9552 - precision: 0.7492 - recall: 0.4751 - val_accuracy: 0.6275 - val_auc: 0.9213 - val_loss: 0.9686 - val_precision: 0.7755 - val_recall: 0.4874 - learning_rate: 1.0000e-16
# Epoch 80/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:14 783ms/step - accuracy: 0.7188 - auc: 0.9456 - loss: 0.7906 - precision: 0.8500 - recall: 0.5312
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.0000000830368326e-17.
#
# Epoch 80: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7188 - auc: 0.9456 - loss: 0.3969 - precision: 0.8500 - recall: 0.5312 - val_accuracy: 0.6316 - val_auc: 0.9381 - val_loss: 0.4415 - val_precision: 0.7500 - val_recall: 0.4737 - learning_rate: 1.0000e-16
# Epoch 81/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.6121 - auc: 0.9146 - loss: 0.9115 - precision: 0.7514 - recall: 0.4683
# Epoch 81: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6121 - auc: 0.9146 - loss: 0.9115 - precision: 0.7514 - recall: 0.4683 - val_accuracy: 0.6270 - val_auc: 0.9210 - val_loss: 0.9700 - val_precision: 0.7742 - val_recall: 0.4874 - learning_rate: 1.0000e-17
# Epoch 82/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:10 767ms/step - accuracy: 0.5938 - auc: 0.8885 - loss: 0.7427 - precision: 0.7143 - recall: 0.3125
# Epoch 82: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5938 - auc: 0.8885 - loss: 0.3728 - precision: 0.7143 - recall: 0.3125 - val_accuracy: 0.6842 - val_auc: 0.9716 - val_loss: 0.3712 - val_precision: 0.9000 - val_recall: 0.4737 - learning_rate: 1.0000e-17
# Epoch 83/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.6168 - auc: 0.9155 - loss: 0.8880 - precision: 0.7581 - recall: 0.4658
# Epoch 83: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6168 - auc: 0.9155 - loss: 0.8881 - precision: 0.7581 - recall: 0.4658 - val_accuracy: 0.6275 - val_auc: 0.9216 - val_loss: 0.9667 - val_precision: 0.7756 - val_recall: 0.4879 - learning_rate: 1.0000e-17
# Epoch 84/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:12 772ms/step - accuracy: 0.5938 - auc: 0.8914 - loss: 1.9087 - precision: 0.6667 - recall: 0.3750
# Epoch 84: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5938 - auc: 0.8914 - loss: 0.9582 - precision: 0.6667 - recall: 0.3750 - val_accuracy: 0.6316 - val_auc: 0.9072 - val_loss: 0.5397 - val_precision: 0.7273 - val_recall: 0.4211 - learning_rate: 1.0000e-17
# Epoch 85/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.6118 - auc: 0.9128 - loss: 0.9494 - precision: 0.7515 - recall: 0.4685
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.0000000664932204e-18.
#
# Epoch 85: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6118 - auc: 0.9128 - loss: 0.9493 - precision: 0.7515 - recall: 0.4685 - val_accuracy: 0.6270 - val_auc: 0.9217 - val_loss: 0.9661 - val_precision: 0.7739 - val_recall: 0.4864 - learning_rate: 1.0000e-17
# Epoch 86/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:23 817ms/step - accuracy: 0.7188 - auc: 0.9294 - loss: 0.6900 - precision: 0.8000 - recall: 0.5000
# Epoch 86: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7188 - auc: 0.9294 - loss: 0.3464 - precision: 0.8000 - recall: 0.5000 - val_accuracy: 0.6842 - val_auc: 0.8890 - val_loss: 0.5750 - val_precision: 0.9167 - val_recall: 0.5789 - learning_rate: 1.0000e-18
# Epoch 87/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.6084 - auc: 0.9096 - loss: 0.9219 - precision: 0.7582 - recall: 0.4652
# Epoch 87: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6084 - auc: 0.9096 - loss: 0.9218 - precision: 0.7581 - recall: 0.4652 - val_accuracy: 0.6280 - val_auc: 0.9217 - val_loss: 0.9661 - val_precision: 0.7761 - val_recall: 0.4874 - learning_rate: 1.0000e-18
# Epoch 88/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:11 771ms/step - accuracy: 0.5625 - auc: 0.8833 - loss: 2.1010 - precision: 0.6818 - recall: 0.4688
# Epoch 88: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5625 - auc: 0.8833 - loss: 1.0547 - precision: 0.6818 - recall: 0.4688 - val_accuracy: 0.5789 - val_auc: 0.8887 - val_loss: 0.5746 - val_precision: 0.6923 - val_recall: 0.4737 - learning_rate: 1.0000e-18
# Epoch 89/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.6191 - auc: 0.9164 - loss: 0.9383 - precision: 0.7626 - recall: 0.4706
# Epoch 89: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.6191 - auc: 0.9164 - loss: 0.9382 - precision: 0.7626 - recall: 0.4706 - val_accuracy: 0.6265 - val_auc: 0.9209 - val_loss: 0.9706 - val_precision: 0.7749 - val_recall: 0.4859 - learning_rate: 1.0000e-18
# Epoch 90/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 790ms/step - accuracy: 0.5000 - auc: 0.8997 - loss: 0.8060 - precision: 0.7059 - recall: 0.3750
# Epoch 90: ReduceLROnPlateau reducing learning rate to 1.000000045813705e-19.
#
# Epoch 90: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5000 - auc: 0.8997 - loss: 0.4046 - precision: 0.7059 - recall: 0.3750 - val_accuracy: 0.7368 - val_auc: 0.9677 - val_loss: 0.3393 - val_precision: 0.8000 - val_recall: 0.6316 - learning_rate: 1.0000e-18
# Epoch 91/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.6096 - auc: 0.9117 - loss: 0.9043 - precision: 0.7518 - recall: 0.4712
# Epoch 91: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6096 - auc: 0.9117 - loss: 0.9043 - precision: 0.7518 - recall: 0.4712 - val_accuracy: 0.6275 - val_auc: 0.9211 - val_loss: 0.9696 - val_precision: 0.7757 - val_recall: 0.4864 - learning_rate: 1.0000e-19
# Epoch 92/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:12 775ms/step - accuracy: 0.6562 - auc: 0.9390 - loss: 0.7905 - precision: 0.7273 - recall: 0.5000
# Epoch 92: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6562 - auc: 0.9390 - loss: 0.3968 - precision: 0.7273 - recall: 0.5000 - val_accuracy: 0.6316 - val_auc: 0.9541 - val_loss: 0.3893 - val_precision: 0.7333 - val_recall: 0.5789 - learning_rate: 1.0000e-19
# Epoch 93/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.6156 - auc: 0.9138 - loss: 0.8965 - precision: 0.7659 - recall: 0.4669
# Epoch 93: val_loss did not improve from 0.26447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6155 - auc: 0.9138 - loss: 0.8966 - precision: 0.7659 - recall: 0.4668 - val_accuracy: 0.6250 - val_auc: 0.9206 - val_loss: 0.9727 - val_precision: 0.7723 - val_recall: 0.4839 - learning_rate: 1.0000e-19
# Epoch 94/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:42 893ms/step - accuracy: 0.5000 - auc: 0.8592 - loss: 0.7382 - precision: 0.6667 - recall: 0.4375
# Epoch 94: val_loss improved from 0.26447 to 0.22946, saving model to run3/models\model_InceptionV3_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5000 - auc: 0.8592 - loss: 0.3706 - precision: 0.6667 - recall: 0.4375 - val_accuracy: 0.8947 - val_auc: 0.9938 - val_loss: 0.2295 - val_precision: 1.0000 - val_recall: 0.8421 - learning_rate: 1.0000e-19
# Epoch 95/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.6138 - auc: 0.9111 - loss: 0.9485 - precision: 0.7565 - recall: 0.4654
# Epoch 95: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6139 - auc: 0.9112 - loss: 0.9484 - precision: 0.7564 - recall: 0.4654 - val_accuracy: 0.6275 - val_auc: 0.9211 - val_loss: 0.9693 - val_precision: 0.7755 - val_recall: 0.4874 - learning_rate: 1.0000e-19
# Epoch 96/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:20 805ms/step - accuracy: 0.3750 - auc: 0.8273 - loss: 1.4549 - precision: 0.5000 - recall: 0.2500
# Epoch 96: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.3750 - auc: 0.8273 - loss: 0.7303 - precision: 0.5000 - recall: 0.2500 - val_accuracy: 0.6316 - val_auc: 0.9554 - val_loss: 0.4081 - val_precision: 0.7500 - val_recall: 0.4737 - learning_rate: 1.0000e-19
# Epoch 97/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.6058 - auc: 0.9115 - loss: 0.9514 - precision: 0.7538 - recall: 0.4662
# Epoch 97: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.6058 - auc: 0.9115 - loss: 0.9512 - precision: 0.7538 - recall: 0.4662 - val_accuracy: 0.6265 - val_auc: 0.9212 - val_loss: 0.9690 - val_precision: 0.7745 - val_recall: 0.4864 - learning_rate: 1.0000e-19
# Epoch 98/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:13 778ms/step - accuracy: 0.6562 - auc: 0.9321 - loss: 0.8542 - precision: 0.8000 - recall: 0.5000
# Epoch 98: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6562 - auc: 0.9321 - loss: 0.4288 - precision: 0.8000 - recall: 0.5000 - val_accuracy: 0.7368 - val_auc: 0.9367 - val_loss: 0.4202 - val_precision: 0.8462 - val_recall: 0.5789 - learning_rate: 1.0000e-19
# Epoch 99/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.6085 - auc: 0.9137 - loss: 0.9155 - precision: 0.7602 - recall: 0.4634
# Epoch 99: ReduceLROnPlateau reducing learning rate to 1.000000032889008e-20.
#
# Epoch 99: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.6085 - auc: 0.9137 - loss: 0.9155 - precision: 0.7602 - recall: 0.4634 - val_accuracy: 0.6285 - val_auc: 0.9216 - val_loss: 0.9669 - val_precision: 0.7763 - val_recall: 0.4879 - learning_rate: 1.0000e-19
# Epoch 100/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:15 784ms/step - accuracy: 0.7188 - auc: 0.9241 - loss: 0.6299 - precision: 0.8947 - recall: 0.5312
# Epoch 100: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7188 - auc: 0.9241 - loss: 0.3162 - precision: 0.8947 - recall: 0.5312 - val_accuracy: 0.5263 - val_auc: 0.9010 - val_loss: 0.5294 - val_precision: 0.6667 - val_recall: 0.4211 - learning_rate: 1.0000e-20
# Epoch 101/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.6124 - auc: 0.9151 - loss: 0.8713 - precision: 0.7679 - recall: 0.4742
# Epoch 101: val_loss did not improve from 0.22946
# ...
# Epoch 119/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.6183 - auc: 0.9144 - loss: 0.9049 - precision: 0.7601 - recall: 0.4692
# Epoch 119: ReduceLROnPlateau reducing learning rate to 1.0000000787060494e-24.
#
# Epoch 119: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.6183 - auc: 0.9144 - loss: 0.9049 - precision: 0.7601 - recall: 0.4692 - val_accuracy: 0.6280 - val_auc: 0.9214 - val_loss: 0.9681 - val_precision: 0.7747 - val_recall: 0.4869 - learning_rate: 1.0000e-23
# Epoch 120/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:39 880ms/step - accuracy: 0.6250 - auc: 0.9354 - loss: 0.7059 - precision: 0.8500 - recall: 0.5312
# Epoch 120: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9354 - loss: 0.3544 - precision: 0.8500 - recall: 0.5312 - val_accuracy: 0.5789 - val_auc: 0.9312 - val_loss: 0.4671 - val_precision: 0.8333 - val_recall: 0.5263 - learning_rate: 1.0000e-24
# Epoch 121/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.6172 - auc: 0.9138 - loss: 0.8933 - precision: 0.7511 - recall: 0.4705
# Epoch 121: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6172 - auc: 0.9138 - loss: 0.8934 - precision: 0.7511 - recall: 0.4705 - val_accuracy: 0.6280 - val_auc: 0.9218 - val_loss: 0.9659 - val_precision: 0.7773 - val_recall: 0.4874 - learning_rate: 1.0000e-24
# Epoch 122/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:12 772ms/step - accuracy: 0.6875 - auc: 0.9195 - loss: 1.2909 - precision: 0.7647 - recall: 0.4062
# Epoch 122: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6875 - auc: 0.9195 - loss: 0.6480 - precision: 0.7647 - recall: 0.4062 - val_accuracy: 0.5789 - val_auc: 0.8883 - val_loss: 0.5840 - val_precision: 0.6000 - val_recall: 0.4737 - learning_rate: 1.0000e-24
# Epoch 123/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.6161 - auc: 0.9116 - loss: 0.9288 - precision: 0.7579 - recall: 0.4672
# Epoch 123: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6161 - auc: 0.9116 - loss: 0.9287 - precision: 0.7579 - recall: 0.4672 - val_accuracy: 0.6300 - val_auc: 0.9220 - val_loss: 0.9646 - val_precision: 0.7757 - val_recall: 0.4899 - learning_rate: 1.0000e-24
# Epoch 124/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 789ms/step - accuracy: 0.5312 - auc: 0.9051 - loss: 0.7508 - precision: 0.7059 - recall: 0.3750
# Epoch 124: ReduceLROnPlateau reducing learning rate to 1.0000001181490946e-25.
#
# Epoch 124: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5312 - auc: 0.9051 - loss: 0.3769 - precision: 0.7059 - recall: 0.3750 - val_accuracy: 0.3684 - val_auc: 0.8500 - val_loss: 0.6513 - val_precision: 0.6667 - val_recall: 0.2105 - learning_rate: 1.0000e-24
# Epoch 125/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.6086 - auc: 0.9113 - loss: 0.9084 - precision: 0.7485 - recall: 0.4694
# Epoch 125: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6086 - auc: 0.9113 - loss: 0.9084 - precision: 0.7485 - recall: 0.4694 - val_accuracy: 0.6265 - val_auc: 0.9212 - val_loss: 0.9689 - val_precision: 0.7749 - val_recall: 0.4859 - learning_rate: 1.0000e-25
# Epoch 126/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:11 769ms/step - accuracy: 0.6250 - auc: 0.9485 - loss: 0.5416 - precision: 0.7826 - recall: 0.5625
# Epoch 126: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9485 - loss: 0.2719 - precision: 0.7826 - recall: 0.5625 - val_accuracy: 0.7368 - val_auc: 0.9351 - val_loss: 0.4251 - val_precision: 0.8000 - val_recall: 0.6316 - learning_rate: 1.0000e-25
# Epoch 127/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.6086 - auc: 0.9131 - loss: 0.9294 - precision: 0.7540 - recall: 0.4684
# Epoch 127: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6087 - auc: 0.9131 - loss: 0.9293 - precision: 0.7539 - recall: 0.4684 - val_accuracy: 0.6265 - val_auc: 0.9214 - val_loss: 0.9682 - val_precision: 0.7748 - val_recall: 0.4874 - learning_rate: 1.0000e-25
# Epoch 128/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:14 782ms/step - accuracy: 0.6875 - auc: 0.9180 - loss: 0.8095 - precision: 0.7391 - recall: 0.5312
# Epoch 128: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6875 - auc: 0.9180 - loss: 0.4064 - precision: 0.7391 - recall: 0.5312 - val_accuracy: 0.7368 - val_auc: 0.9266 - val_loss: 0.4632 - val_precision: 0.8182 - val_recall: 0.4737 - learning_rate: 1.0000e-25
# Epoch 129/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.6031 - auc: 0.9116 - loss: 0.9487 - precision: 0.7415 - recall: 0.4637
# Epoch 129: ReduceLROnPlateau reducing learning rate to 1.0000001428009978e-26.
#
# Epoch 129: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6031 - auc: 0.9116 - loss: 0.9486 - precision: 0.7416 - recall: 0.4637 - val_accuracy: 0.6295 - val_auc: 0.9223 - val_loss: 0.9629 - val_precision: 0.7788 - val_recall: 0.4899 - learning_rate: 1.0000e-25
# Epoch 130/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:14 781ms/step - accuracy: 0.7812 - auc: 0.9313 - loss: 0.7851 - precision: 0.8077 - recall: 0.6562
# Epoch 130: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7812 - auc: 0.9313 - loss: 0.3941 - precision: 0.8077 - recall: 0.6562 - val_accuracy: 0.4211 - val_auc: 0.8167 - val_loss: 0.7424 - val_precision: 0.3636 - val_recall: 0.2105 - learning_rate: 1.0000e-26
# Epoch 131/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.6013 - auc: 0.9102 - loss: 0.9364 - precision: 0.7555 - recall: 0.4648
# Epoch 131: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.6013 - auc: 0.9102 - loss: 0.9363 - precision: 0.7555 - recall: 0.4649 - val_accuracy: 0.6265 - val_auc: 0.9211 - val_loss: 0.9697 - val_precision: 0.7742 - val_recall: 0.4874 - learning_rate: 1.0000e-26
# Epoch 132/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:15 784ms/step - accuracy: 0.6562 - auc: 0.9039 - loss: 0.6821 - precision: 0.6818 - recall: 0.4688
# Epoch 132: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6562 - auc: 0.9039 - loss: 0.3424 - precision: 0.6818 - recall: 0.4688 - val_accuracy: 0.7368 - val_auc: 0.9640 - val_loss: 0.3846 - val_precision: 0.9000 - val_recall: 0.4737 - learning_rate: 1.0000e-26
# Epoch 133/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.6129 - auc: 0.9116 - loss: 0.9231 - precision: 0.7483 - recall: 0.4695
# Epoch 133: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6129 - auc: 0.9116 - loss: 0.9231 - precision: 0.7483 - recall: 0.4694 - val_accuracy: 0.6275 - val_auc: 0.9212 - val_loss: 0.9691 - val_precision: 0.7753 - val_recall: 0.4869 - learning_rate: 1.0000e-26
# Epoch 134/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:11 770ms/step - accuracy: 0.6875 - auc: 0.9178 - loss: 0.8513 - precision: 0.7143 - recall: 0.4688
# Epoch 134: ReduceLROnPlateau reducing learning rate to 1.000000142800998e-27.
#
# Epoch 134: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc: 0.9178 - loss: 0.4273 - precision: 0.7143 - recall: 0.4688 - val_accuracy: 0.6316 - val_auc: 0.9439 - val_loss: 0.4151 - val_precision: 0.7692 - val_recall: 0.5263 - learning_rate: 1.0000e-26
# Epoch 135/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.5997 - auc: 0.9108 - loss: 0.9063 - precision: 0.7429 - recall: 0.4661
# Epoch 135: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.5997 - auc: 0.9108 - loss: 0.9063 - precision: 0.7429 - recall: 0.4661 - val_accuracy: 0.6270 - val_auc: 0.9212 - val_loss: 0.9692 - val_precision: 0.7745 - val_recall: 0.4864 - learning_rate: 1.0000e-27
# Epoch 136/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:22 815ms/step - accuracy: 0.5938 - auc: 0.9330 - loss: 1.0289 - precision: 0.7619 - recall: 0.5000
# Epoch 136: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5938 - auc: 0.9330 - loss: 0.5165 - precision: 0.7619 - recall: 0.5000 - val_accuracy: 0.6842 - val_auc: 0.9451 - val_loss: 0.4100 - val_precision: 0.8462 - val_recall: 0.5789 - learning_rate: 1.0000e-27
# Epoch 137/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.6084 - auc: 0.9134 - loss: 0.9157 - precision: 0.7482 - recall: 0.4638
# Epoch 137: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6084 - auc: 0.9134 - loss: 0.9157 - precision: 0.7482 - recall: 0.4638 - val_accuracy: 0.6290 - val_auc: 0.9217 - val_loss: 0.9660 - val_precision: 0.7750 - val_recall: 0.4879 - learning_rate: 1.0000e-27
# Epoch 138/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:15 787ms/step - accuracy: 0.6250 - auc: 0.9473 - loss: 0.7002 - precision: 0.8095 - recall: 0.5312
# Epoch 138: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6250 - auc: 0.9473 - loss: 0.3515 - precision: 0.8095 - recall: 0.5312 - val_accuracy: 0.4737 - val_auc: 0.8820 - val_loss: 0.5797 - val_precision: 0.8000 - val_recall: 0.4211 - learning_rate: 1.0000e-27
# Epoch 139/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.6149 - auc: 0.9152 - loss: 0.9165 - precision: 0.7486 - recall: 0.4688
# Epoch 139: ReduceLROnPlateau reducing learning rate to 1.0000001235416984e-28.
#
# Epoch 139: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6149 - auc: 0.9152 - loss: 0.9164 - precision: 0.7486 - recall: 0.4688 - val_accuracy: 0.6280 - val_auc: 0.9215 - val_loss: 0.9671 - val_precision: 0.7752 - val_recall: 0.4884 - learning_rate: 1.0000e-27
# Epoch 140/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:24 821ms/step - accuracy: 0.5625 - auc: 0.8967 - loss: 0.9981 - precision: 0.8333 - recall: 0.4688
# Epoch 140: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5625 - auc: 0.8967 - loss: 0.5011 - precision: 0.8333 - recall: 0.4688 - val_accuracy: 0.5789 - val_auc: 0.9095 - val_loss: 0.5201 - val_precision: 0.7778 - val_recall: 0.3684 - learning_rate: 1.0000e-28
# Epoch 141/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.6068 - auc: 0.9110 - loss: 0.9449 - precision: 0.7544 - recall: 0.4658
# Epoch 141: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6068 - auc: 0.9110 - loss: 0.9448 - precision: 0.7544 - recall: 0.4658 - val_accuracy: 0.6260 - val_auc: 0.9208 - val_loss: 0.9716 - val_precision: 0.7739 - val_recall: 0.4849 - learning_rate: 1.0000e-28
# Epoch 142/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:14 783ms/step - accuracy: 0.5625 - auc: 0.8692 - loss: 0.7874 - precision: 0.7059 - recall: 0.3750
# Epoch 142: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5625 - auc: 0.8692 - loss: 0.3953 - precision: 0.7059 - recall: 0.3750 - val_accuracy: 0.7895 - val_auc: 0.9765 - val_loss: 0.2866 - val_precision: 0.8750 - val_recall: 0.7368 - learning_rate: 1.0000e-28
# Epoch 143/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.6052 - auc: 0.9094 - loss: 0.8771 - precision: 0.7469 - recall: 0.4637
# Epoch 143: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6053 - auc: 0.9094 - loss: 0.8772 - precision: 0.7469 - recall: 0.4638 - val_accuracy: 0.6280 - val_auc: 0.9215 - val_loss: 0.9674 - val_precision: 0.7763 - val_recall: 0.4879 - learning_rate: 1.0000e-28
# Epoch 144/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:20 806ms/step - accuracy: 0.5312 - auc: 0.8944 - loss: 0.5957 - precision: 0.7619 - recall: 0.5000
# Epoch 144: ReduceLROnPlateau reducing learning rate to 1.0000001235416985e-29.
#
# Epoch 144: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5312 - auc: 0.8944 - loss: 0.2991 - precision: 0.7619 - recall: 0.5000 - val_accuracy: 0.5789 - val_auc: 0.9160 - val_loss: 0.5031 - val_precision: 0.6667 - val_recall: 0.4211 - learning_rate: 1.0000e-28
# Epoch 145/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.6104 - auc: 0.9127 - loss: 0.8968 - precision: 0.7444 - recall: 0.4622
# Epoch 145: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 0.6104 - auc: 0.9127 - loss: 0.8968 - precision: 0.7444 - recall: 0.4622 - val_accuracy: 0.6285 - val_auc: 0.9216 - val_loss: 0.9667 - val_precision: 0.7764 - val_recall: 0.4884 - learning_rate: 1.0000e-29
# Epoch 146/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 789ms/step - accuracy: 0.6875 - auc: 0.9381 - loss: 0.9447 - precision: 0.8421 - recall: 0.5000
# Epoch 146: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc: 0.9381 - loss: 0.4742 - precision: 0.8421 - recall: 0.5000 - val_accuracy: 0.5263 - val_auc: 0.9035 - val_loss: 0.5416 - val_precision: 0.6364 - val_recall: 0.3684 - learning_rate: 1.0000e-29
# Epoch 147/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.6067 - auc: 0.9127 - loss: 0.9349 - precision: 0.7558 - recall: 0.4670
# Epoch 147: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.6067 - auc: 0.9127 - loss: 0.9347 - precision: 0.7558 - recall: 0.4670 - val_accuracy: 0.6270 - val_auc: 0.9214 - val_loss: 0.9682 - val_precision: 0.7755 - val_recall: 0.4874 - learning_rate: 1.0000e-29
# Epoch 148/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 1:11 285ms/step - accuracy: 0.7500 - auc: 0.9462 - loss: 1.0199 - precision: 0.8750 - recall: 0.5833
# Epoch 148: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7500 - auc: 0.9462 - loss: 0.5120 - precision: 0.8750 - recall: 0.5833 - val_accuracy: 0.6842 - val_auc: 0.9287 - val_loss: 0.4632 - val_precision: 0.7500 - val_recall: 0.4737 - learning_rate: 1.0000e-29
# Epoch 149/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - accuracy: 0.6146 - auc: 0.9143 - loss: 0.9160 - precision: 0.7611 - recall: 0.4745
# Epoch 149: ReduceLROnPlateau reducing learning rate to 1.0000001536343539e-30.
#
# Epoch 149: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6146 - auc: 0.9143 - loss: 0.9160 - precision: 0.7611 - recall: 0.4745 - val_accuracy: 0.6275 - val_auc: 0.9214 - val_loss: 0.9677 - val_precision: 0.7750 - val_recall: 0.4879 - learning_rate: 1.0000e-29
# Epoch 150/150
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:14 783ms/step - accuracy: 0.5000 - auc: 0.8714 - loss: 1.0142 - precision: 0.6842 - recall: 0.4062
# Epoch 150: val_loss did not improve from 0.22946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5000 - auc: 0.8714 - loss: 0.5091 - precision: 0.6842 - recall: 0.4062 - val_accuracy: 0.6316 - val_auc: 0.9243 - val_loss: 0.4915 - val_precision: 0.8000 - val_recall: 0.4211 - learning_rate: 1.0000e-30
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 51s 802ms/step - accuracy: 0.6140 - auc: 0.9159 - loss: 0.9981 - precision: 0.7606 - recall: 0.4736
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: InceptionV3, Optimizer: Adam
# Validation Loss: 0.9647
# Validation Accuracy: 0.6276
# Validation Precision: 0.9214
# Validation Recall: 0.7752
# Validation AUC-ROC: 0.4873

# %% [markdown]
# # Weight Checking

# %%
# Importing Dependencies
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger

import csv
import os

from sklearn.utils import class_weight

# Creating a CSV file to store the model results
csv_file = "model_results.csv"
fieldnames = [
    "architecture",
    "optimizer",
    "loss",
    "accuracy",
    "precision",
    "recall",
    "auc",
]

# Write the header to the CSV file. Data is written to the file after model_result
with open(csv_file, mode="w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()

batch_size = 32
architectures = ["VGG16", "ResNet50", "InceptionV3"]
optimizers = ["Adam", "RMSprop", "SGD"]

# Create directory to store models
models_dir = "models"
os.makedirs(models_dir, exist_ok=True)

# Initialize model_results to store the evaluation results
model_results = []

for architecture in architectures:
    # Set the input shape and preprocessing function based on the selected architecture
    if architecture == "VGG16" or architecture == "ResNet50":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.vgg16.preprocess_input
    elif architecture == "InceptionV3":
        input_shape = (299, 299, 3)
        preprocessing_function = tf.keras.applications.inception_v3.preprocess_input

    # Load and preprocess data using tf.keras.preprocessing
    # This is add data augmentation to the training dataset
    train_datagen = ImageDataGenerator(
        preprocessing_function=preprocessing_function,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
    )

    train_dataset = train_datagen.flow_from_directory(
        "Resources/Skin Cancer/train",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    
    val_datagen = ImageDataGenerator(preprocessing_function=preprocessing_function)

    # Define the validation dataset without data augmentation
    val_dataset = val_datagen.flow_from_directory(
        "Resources/Skin Cancer/val",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    # Define the pre-trained model architecture. Will select proper model based on current 'architecture' in for loop
    if architecture == "VGG16":
        base_model = VGG16(
            weights="imagenet", include_top=False, input_shape=input_shape
        )
    elif architecture == "ResNet50":
        base_model = ResNet50(
            weights="imagenet", include_top=False, input_shape=input_shape
        )
    elif architecture == "InceptionV3":
        base_model = InceptionV3(
            weights="imagenet", include_top=False, input_shape=input_shape
        )

    # Freeze the layers of the pre-trained model
    for layer in base_model.layers:
        layer.trainable = False

    # Get the number of unique classes from the train_dataset
    num_classes = len(train_dataset.class_indices)

    # Add custom layers on top of the pre-trained model
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation="softmax")(x)

    # Create the final model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Step through and adjust for each optimizer
    for optimizer_name in optimizers:
        # Define the optimizer
        # Learning rate is the size of the step the optimizer will take to minimize the loss function
        if optimizer_name == "Adam":
            optimizer = Adam(learning_rate=0.001)
        elif optimizer_name == "RMSprop":
            optimizer = RMSprop(learning_rate=0.001)
        elif optimizer_name == "SGD":
            optimizer = SGD(learning_rate=0.001, momentum=0.9)

        # Create learning rate scheduler that monitors validation loss
        lr_scheduler = ReduceLROnPlateau(
            monitor="val_loss", factor=0.1, patience=5, verbose=1
        )

        # Compile the model
        model.compile(
            optimizer=optimizer,
            loss="categorical_crossentropy",
            metrics=["accuracy", Precision(), Recall(), AUC()],
        )

        # Create a TensorBoard callback with a separate log directory for each model and optimizer
        tensorboard_callback = TensorBoard(
            log_dir=f"./logs/{architecture}_{optimizer_name}", histogram_freq=1
        )

        # Create an EarlyStopping callback to prevent overfitting
        early_stopping = EarlyStopping(
            monitor="val_loss", patience=5, restore_best_weights=True
        )

        # Create a ModelCheckpoint callback to save the best model weights
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath=os.path.join(
                models_dir, f"model_{architecture}_{optimizer_name}.weights.h5"
            ),
            save_weights_only=True,
            save_best_only=True,
            monitor="val_loss",
            verbose=1,
        )

        # Create a CSVLogger callback with keras
        csv_logger = CSVLogger(
            os.path.join(
                models_dir, f"model_{architecture}_{optimizer_name}_training.csv"
            )
        )

        # Calculate class weights
        # This step is required, as some of the classes are imbalanced, in particular, the val classes
        class_weights = class_weight.compute_class_weight(
            'balanced',
            classes=np.unique(train_dataset.classes),
            y=train_dataset.classes
        )
        class_weight_dict = dict(enumerate(class_weights))

# %%
print(class_weights)
print(class_weight_dict)

# %% [markdown]
# # Resume from Interrupt
# Should the overnight run need to be interupted, it is possible to pick up where the interruption left off, and continue training the model

# %%
# Load the model architecture and optimizer
architecture = "VGG16"  # Specify the architecture you want to resume training for
optimizer_name = "Adam"  # Specify the optimizer you want to resume training with

# Load the model 
model = load_model(os.path.join(models_dir, f"model_{architecture}_{optimizer_name}.h5"))

# Load the optimizer state
with open(os.path.join(models_dir, f"model_{architecture}_{optimizer_name}_optimizer_state.pkl"), 'rb') as f:
    optimizer_weights = model.load(f)
    model.optimizer.set_weights(optimizer_weights)

# Resume training from a specific epoch
resume_epoch = 5  # Specify the epoch number to resume from
for epoch in range(resume_epoch, epochs):
    history = model.fit(
        train_dataset,
        steps_per_epoch=train_dataset.samples // 32,
        validation_data=val_dataset,
        validation_steps=val_dataset.samples // 32,
        epochs=1,
        callbacks=[tensorboard_callback, lr_scheduler, checkpoint_callback],
        initial_epoch=epoch
    )

    # Save the optimizer state
    with open(os.path.join(models_dir, f"model_{architecture}_{optimizer_name}_optimizer_state.pkl"), 'wb') as f:
        model.dump(model.optimizer.get_weights(), f)

     # Save the optimizer state
    with open(
                os.path.join(
                    models_dir,
                    f"model_{architecture}_{optimizer_name}_optimizer_state.pkl",
                ),
                "wb",
            ) as f:
                model.dump(model.optimizer.get_weights(), f)

        # Evaluate the model on the validation set
        loss, accuracy, precision, recall, auc = model.evaluate(val_dataset)
        print(f"Model: {architecture}, Optimizer: {optimizer_name}")
        print(f"Validation Loss: {loss:.4f}")
        print(f"Validation Accuracy: {accuracy:.4f}")
        print(f"Validation Precision: {precision:.4f}")
        print(f"Validation Recall: {recall:.4f}")
        print(f"Validation AUC-ROC: {auc:.4f}")

        # Append the model results to the list
        model_results.append(
            {
                "architecture": architecture,
                "optimizer": optimizer_name,
                "loss": loss,
                "accuracy": accuracy,
                "precision": precision,
                "recall": recall,
                "auc": auc,
            }
        )
        # Save the model
        model.save(
            os.path.join(models_dir, f"model_{architecture}_{optimizer_name}.h5")
        )

# %% [markdown]
# # Evaluating and Visualizing the Data

# %%
# Importing Dependencies
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import csv
import os

from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import os

model_results = "model_results.csv"

# Run Number - use to create new directory or add to existing directory
run_number = 3
run_dir = f"run{run_number}"
os.makedirs(run_dir, exist_ok=True)


architectures = ["InceptionV3"] # Options: "VGG16", "ResNet50", "InceptionV3"
optimizers = ["Adam"] # Options: "Adam", "RMSprop", "SGD"

batch_size = 32

# Define the preprocessing function based on the architectures you want to visualize
architectures_to_visualize = ["ResNet50"]  # Specify the architectures you want to visualize
preprocessing_functions = {
    "VGG16": tf.keras.applications.vgg16.preprocess_input,
    "ResNet50": tf.keras.applications.resnet50.preprocess_input,
    "InceptionV3": tf.keras.applications.inception_v3.preprocess_input
}


# Create a directory to store the visualization results
visualizations_dir = f"{run_dir}/visualizations"
os.makedirs(visualizations_dir, exist_ok=True)

#

# Iterate over each model architecture and optimizer
for architecture in architectures:
    # Set the preprocessing function based on the architecture
    preprocessing_function = preprocessing_functions[architecture]

    # Set the input shape and preprocessing function based on the selected architecture
    if architecture == "VGG16":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.vgg16.preprocess_input
    if architecture == "ResNet50":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.resnet50.preprocess_input
    elif architecture == "InceptionV3":
        input_shape = (299, 299, 3)
        preprocessing_function = tf.keras.applications.inception_v3.preprocess_input

    # Redefine the validation dataset with the corresponding preprocessing function
    val_datagen = ImageDataGenerator(preprocessing_function=preprocessing_function)
    val_dataset = val_datagen.flow_from_directory(
        "Resources/Skin Cancer/val",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    # Get the class names from the redefined val_dataset
    class_names = list(val_dataset.class_indices.keys())


    for optimizer_name in optimizers:
        # Load the trained model
        model = load_model(os.path.join(f"{run_dir}/models/", f"model_{architecture}_{optimizer_name}.h5"))

        # Make predictions on the validation dataset using the redefined val_dataset
        y_pred = model.predict(val_dataset)
        y_pred_classes = np.argmax(y_pred, axis=1)

        # Get the true labels of the validation dataset
        y_true = val_dataset.classes

        # Compute the confusion matrix
        cm = confusion_matrix(y_true, y_pred_classes)
        print(f"Confusion Matrix for {architecture}_{optimizer_name}:")
        print(cm)

        # Save the confusion matrix as a CSV file
        cm_filename = f"confusion_matrix_{architecture}_{optimizer_name}.csv"
        np.savetxt(os.path.join(visualizations_dir, cm_filename), cm, delimiter=",")

        # Compute the classification report
        cr = classification_report(y_true, y_pred_classes, target_names=class_names)
        print(f"Classification Report for {architecture}_{optimizer_name}:")
        print(cr)

        # Save the classification report as a text file
        cr_filename = f"classification_report_{architecture}_{optimizer_name}.txt"
        with open(os.path.join(visualizations_dir, cr_filename), "w") as file:
            file.write(cr)

        # Compute the ROC curve and AUC for each class
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(len(class_names)):
            fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])

        # Plot the ROC curve for each class
        plt.figure(figsize=(8, 6))
        for i in range(len(class_names)):
            plt.plot(
                fpr[i],
                tpr[i],
                label=f"ROC curve of class {class_names[i]} (AUC = {roc_auc[i]:.2f})",
            )
        plt.plot([0, 1], [0, 1], "k--")
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve for {architecture}_{optimizer_name}")
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.savefig(os.path.join(visualizations_dir, f"roc_curve_{architecture}_{optimizer_name}.png"))
        plt.close()

        # Visualize the model's predictions on a subset of the validation data
        subset_size = 10
        subset_indices = np.random.choice(len(val_dataset), subset_size, replace=False)
        subset_images = []
        subset_labels = []
        val_dataset.reset()  # Reset the validation dataset iterator
        for i in range(len(val_dataset)):
            if i in subset_indices:
                image_batch, label_batch = next(val_dataset)
                for image, label in zip(image_batch, label_batch):
                    subset_images.append(image)
                    subset_labels.append(label)

        subset_images = np.array(subset_images)
        subset_labels = np.array(subset_labels)

        subset_preds = model.predict(subset_images)
        subset_pred_classes = np.argmax(subset_preds, axis=1)

        # Generate the visualization plot
        plt.figure(figsize=(15, 10))
        for i in range(subset_size):
            plt.subplot(2, 5, i + 1)
            plt.imshow(subset_images[i])
            plt.title(
                f"True: {class_names[np.argmax(subset_labels[i])]}\\nPred: {class_names[subset_pred_classes[i]]}"
            )
            plt.axis("off")
        plt.tight_layout()
        plt.savefig(os.path.join(visualizations_dir, f"predictions_{architecture}_{optimizer_name}.png"))
        plt.close()


# Read the CSV file and store the model results
model_results = []
with open("model_results.csv", "r") as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        model_results.append(row)

# Create a bar plot for validation precision
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["precision"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation Precision")
plt.title("Validation Precision for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_precision_comparison.png"))
plt.close()

# Create a bar plot for validation recall
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["recall"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation Recall")
plt.title("Validation Recall for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_recall_comparison.png"))
plt.close()

# Create a bar plot for validation AUC-ROC
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["auc"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation AUC-ROC")
plt.title("Validation AUC-ROC for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_auc_comparison.png"))
plt.close()
# Out:
# Found 2003 images belonging to 7 classes.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 832ms/step
# Confusion Matrix for InceptionV3_Adam:
# [[  3   3   7   3  12  34   3]
#  [  6   9   7   3  24  49   5]
#  [ 18  16  16  12  36 112  10]
#  [  2   0   2   0   6   9   4]
#  [ 23  21  25  10  39  95  10]
#  [ 90 116 131  57 236 664  47]
#  [  2   1   2   1   4  17   1]]
# Classification Report for InceptionV3_Adam:
#               precision    recall  f1-score   support
#
#        akiec       0.02      0.05      0.03        65
#          bcc       0.05      0.09      0.07       103
#          bkl       0.08      0.07      0.08       220
#           df       0.00      0.00      0.00        23
#          mel       0.11      0.17      0.13       223
#           nv       0.68      0.50      0.57      1341
#         vasc       0.01      0.04      0.02        28
#
#     accuracy                           0.37      2003
#    macro avg       0.14      0.13      0.13      2003
# weighted avg       0.48      0.37      0.41      2003
#
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 791ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Creating Visualizations Outside of Loop

# %%
# Importing Dependencies
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger

import csv
import os

from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import os


visualizations_dir = "visualizations"

## Read the CSV file and store the model results
model_results = []
with open("model_results.csv", "r") as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        model_results.append(row)

# Create a bar plot for validation precision
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["precision"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation Precision")
plt.title("Validation Precision for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_precision_comparison.png"))
plt.close()

# Create a bar plot for validation recall
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["recall"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation Recall")
plt.title("Validation Recall for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_recall_comparison.png"))
plt.close()

# Create a bar plot for validation AUC-ROC
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["auc"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation AUC-ROC")
plt.title("Validation AUC-ROC for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_auc_comparison.png"))
plt.close()
